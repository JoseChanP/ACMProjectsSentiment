# %%
import pandas as pd
import nltk
import string
nltk.download('vader_lexicon')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

headlines_df = pd.read_csv('final.csv')
headlines_df.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jose/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/jose/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jose/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jose/nltk_data...
#   Ticker                                              Title  \
# 0   CHDN  Casino and gaming stocks fall amid growing rec...
# 1   CHDN  Churchill Downs Outperforms with Strong Q2, Pr...
# 2   CHDN  Churchill Downs Inc. hosts conference call for...
# 3   CHDN  Churchill Downs Incorporated Reveals Grandstan...
# 4   CHDN           Notable earnings after Wednesday's close
#
#                     Date
# 0    8/5/2024 3:27:04 PM
# 1   7/26/2024 6:05:25 PM
# 2   7/25/2024 2:45:00 PM
# 3  7/24/2024 10:05:31 PM
# ...

# %%
headlines_df['Title'] = headlines_df['Title'].str.lower().str.translate(str.maketrans('','', string.punctuation)) # Convert 'text' column to string data type
headlines_df['Title'] = headlines_df['Title'].apply(word_tokenize)
stopwords = set(stopwords.words('english'))
headlines_df['Title'] = headlines_df['Title'].apply(lambda x: [word for word in x if word not in stopwords])
lemmatizer = WordNetLemmatizer()
headlines_df['Title'] = headlines_df['Title'].apply(lambda x: [lemmatizer.lemmatize(token) for token in x])
headlines_df
# Out:
#        Ticker                                              Title  \
# 0        CHDN  [casino, gaming, stock, fall, amid, growing, r...
# 1        CHDN  [churchill, down, outperforms, strong, q2, pro...
# 2        CHDN  [churchill, down, inc, host, conference, call,...
# 3        CHDN  [churchill, down, incorporated, reveals, grand...
# 4        CHDN              [notable, earnings, wednesday, close]
# ...       ...                                                ...
# 756170    IBM  [ibm, vodafone, extends, outsourcing, deal, 1,...
# 756171    IBM    [u, stock, rise, strength, ibm, housing, start]
# 756172    IBM  [bharti, say, ibm, provide, solution, africa, ...
# 756173    IBM      [ibm, ink, 664, mln, outsourcing, deal, iifl]
# 756174    IBM          [ibm, overtakes, microsofts, market, cap]
#
#                          Date
# 0         8/5/2024 3:27:04 PM
# 1        7/26/2024 6:05:25 PM
# 2        7/25/2024 2:45:00 PM
# 3       7/24/2024 10:05:31 PM
# ...
